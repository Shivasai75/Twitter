# %%
import pandas as pd 
import tweepy 
  
  
#function to display data of each tweet 
def printtweetdata(n, ith_tweet): 
    
    print(f"Tweet {n}:") 
    print(f"Username:{ith_tweet[0]}") 
    print(f"Description:{ith_tweet[1]}") 
    print(f"Location:{ith_tweet[2]}") 
    print(f"Following Count:{ith_tweet[3]}") 
    print(f"Follower Count:{ith_tweet[4]}") 
    print(f"Total Tweets:{ith_tweet[5]}") 
    print(f"Retweet Count:{ith_tweet[6]}") 
    print(f"Tweet Text:{ith_tweet[7]}") 
    print(f"Hashtags Used:{ith_tweet[8]}") 
  
  

def scrape(words, date_since, numtweet): 
      
    # Creating DataFrame using pandas 
    db = pd.DataFrame(columns=['username', 'description', 'location', 'following', 
                               'followers', 'totaltweets', 'retweetcount', 'text', 'hashtags']) 
      
    
    tweets = tweepy.Cursor(api.search, q=words, lang="en", 
                           since=date_since, tweet_mode='extended').items(numtweet) 
     
   
    list_tweets = [tweet for tweet in tweets]  
    i = 1  
      
     
    for tweet in list_tweets: 
        username = tweet.user.screen_name 
        description = tweet.user.description 
        location = tweet.user.location 
        following = tweet.user.friends_count 
        followers = tweet.user.followers_count 
        totaltweets = tweet.user.statuses_count 
        retweetcount = tweet.retweet_count 
        hashtags = tweet.entities['hashtags'] 
          
         
        try: 
            text = tweet.retweeted_status.full_text 
        except AttributeError: 
            text = tweet.full_text 
        hashtext = list() 
        for j in range(0, len(hashtags)): 
            hashtext.append(hashtags[j]['text']) 
          
         
        ith_tweet = [username, description, location, following, 
                     followers, totaltweets, retweetcount, text, hashtext] 
        db.loc[len(db)] = ith_tweet 
          
        
        printtweetdata(i, ith_tweet) 
        i = i+1
    filename = 'scraped_tweets.csv'
      
     
    db.to_csv(filename) 
  
  
if __name__ == '__main__': 
      
     
    consumer_key = "OfBS4N2enL8PEw2HJI0zS0WbI"
    consumer_secret = "Siw8e7Kl7F29H0foRvR5lLeDlGD17V0tKZxxhoGBKm9Fk4x9gd"
    access_key = "2617230702-YFc611yMYaZKQSBc1BbR7SkUIw0QFlfk3h5kHmg"
    access_secret = "xlKTTeqYuHUMXXXrKpdwm5CR54O8UZ2c8FsNTdjB4ZfOM"
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
    auth.set_access_token(access_key, access_secret) 
    api = tweepy.API(auth) 
      
    
    print("Enter Twitter HashTag to search for") 
    words = input() 
    print("Enter Date since The Tweets are required in yyyy-mm--dd") 
    date_since = input() 
      
    
    numtweet = 100  
    scrape(words, date_since, numtweet) 
    print('Scraping has completed!')
# Out:
# Enter Twitter HashTag to search for
# JoeBiden
# Enter Date since The Tweets are required in yyyy-mm--dd
# 2007-04-01
# Tweet 1:
# Username:UncleMcFly
# Description:31. JetLife. GOLF. #Shane100 Member. ig: unclemcflyy. tiktok: unclemcfly. #RIPMister818. “Craig with a Triangle” -@jasonnash cashapp: $UncleMcFlyy
# Location:∆TL∆NT∆, G∆
# Following Count:4289
# Follower Count:2491
# Total Tweets:301953
# Retweet Count:12100
# Tweet Text:Dear @JoeBiden Now that you're the prez could u do a me a quick favor and undo your old crime bill, decriminalize all drugs, ban fracking, reunite immigrant families, eliminate the electoral college, cancel student loan debt, and say yes to universal health care? Thanks bud! 🇺🇸
# Hashtags Used:[]
# Tweet 2:
# Username:Syrianj
# Description:Human and civil rights activist. Family oriented. Free Syrian
# Location:ِAleppo, Syria
# Following Count:175
# Follower Count:219
# Total Tweets:36057
# Retweet Count:14
# Tweet Text:.@WadeCrowfoot, @calnatresources Sec, says @JoeBiden will better fund CA's federal land management.
#
# Last year, 5 out of the 6 largest fires in CA history were burning AT THE SAME TIME.
#
# He says @CAgovernor @GavinNewsom recently committed $1 billion for wildfire prevention. https://t.co/ERBhJf3tut
# Hashtags Used:[]
# Tweet 3:
# Username:CH99179346
# Description:Russian bot?
# Buy the ticket, take the ride....
# Location:
# Following Count:178
# Follower Count:16
# Total Tweets:762
# Retweet Count:0
# Tweet Text:@TheFirstonTV @JoeBiden Let's see him. Make a complete jackass of himself, then everyone will see trump was better
# Hashtags Used:[]
# Tweet 4:
# Username:tickerNEWSau
# Description:Streaming News. Now. 🌎 🖥 Ticker covers the latest in news, business, entertainment, and tech. Live weekdays from 8am AEDT.
# Location:International News Channel
# Following Count:629
# Follower Count:4512
# Total Tweets:7023
# Retweet Count:0
# Tweet Text:US President @JoeBiden ’s approval rating in his first days in office is higher than Donald Trump ever achieved during his four years as president.
#
# #tickerNEWS | https://t.co/qbweIBPee8 https://t.co/xLiDU8kR5j
# Hashtags Used:['tickerNEWS']
# Tweet 5:
# Username:Sergiy1975Zorro
# Description:engineer, manager and just a happy father and husband from Ukraine
# Location:
# Following Count:145
# Follower Count:29
# Total Tweets:1580
# Retweet Count:0
# Tweet Text:@PressSec @ABlinken @StateDept #DV2020 need your help!!We are DIVERSITY VISA holders, We’ve been waiting for almost 2 years, our visas will expire in early March, please help us to remove Trumps proclamation PP10014 and related! We’re running out of time #dv2020 #immigrants #noban @JoeBiden @WhiteHouse @POTUS
# Hashtags Used:['DV2020', 'dv2020', 'immigrants', 'noban']
# Tweet 6:
# Username:ChuckerDean
# Description:Australian | Speedway | Supercross
# Location:Australia
# Following Count:56
# Follower Count:3
# Total Tweets:11
# Retweet Count:0
# Tweet Text:Comedians Tried to Warn You of Biden's Stupidity - Get to Know The Puppet https://t.co/F42hKaRPqh via @YouTube @JoeBiden shame Robin wasn’t around to see the dribble that comes out of your mouth these days. He could have toured for a year off your presidential campaign 😳
# Hashtags Used:[]
# Tweet 7:
# Username:Ahmad78147218
# Description:Simplicity
# Location:
# Following Count:52
# Follower Count:44
# Total Tweets:160
# Retweet Count:267
# Tweet Text:It is imperative for Biden Administration to keep US FORCES in AFG to uphold U.S influence in the region by taking punitive actions against China &amp; ISI by refraining them to influence the peace process in AFG
#
# @ABlinken
# @JoeBiden
# @KamalaHarris
# @PMOIndia
# @ARS19622906
# @CIA
# Hashtags Used:[]
# Tweet 8:
# Username:GlenWoodfin
# Description:Web Design & SEO
# Location:Acapulco, Mexico
# Following Count:41243
# Follower Count:60024
# Total Tweets:97158
# Retweet Count:0
# Tweet Text:.@JoeBiden, where is your 'build back better'? https://t.co/6CvHOXSTJW
# Hashtags Used:[]
# Tweet 9:
# Username:eloracnasus
# Description:Pro-God pro-life pro-gun pro-military pro-constitution.  STAND WITH ISRAEL!
#
# XX
# Location:Clevelander in lewiston Idaho
# Following Count:2349
# Follower Count:2655
# Total Tweets:66633
# Retweet Count:0
# Tweet Text:All hail DiCK tator @JoeBiden @potus @WhiteHouse @PressSec @TheDemocrats
#
# #Hypocrites #Dictator #DictatorBiden https://t.co/rXp8db7l21
# Hashtags Used:['Hypocrites', 'Dictator', 'DictatorBiden']
# Tweet 10:
# Username:Saba09248785
# Description:
# Location:
# Following Count:110
# Follower Count:77
# Total Tweets:1222
# Retweet Count:0
# Tweet Text:86 days of #WarOnTigray #FamineOnTigray no telecommunications, no internet, no water, no food, no medicine, no hospitals. #HumanitarianCorridor NOW!
# @POTUS @VP @JoeBiden @SecBlinken @jakejsullivan @LindaT_G @AmbassadorRice #BidenTakeActionNow
# Hashtags Used:['WarOnTigray', 'FamineOnTigray', 'HumanitarianCorridor', 'BidenTakeActionNow']
# Tweet 11:
# Username:PaulM61348190
# Description:
# Location:
# Following Count:33
# Follower Count:54
# Total Tweets:16277
# Retweet Count:232
# Tweet Text:👇🏾The issue in America 👇🏾
# @JoeBiden 78yrs old
# @SpeakerPelosi - 80
# @chuckschumer -70
# @RepMaxineWaters - 82
# @LeaderMcConnell - 78
# @gracenapolitano - 83
# @RepHastingsFL - 83
# @BillPascrell - 83
# @eddieberniecejohnson - 84
# @dianefeinstine - 86
# Aged politicians need to be replaced!
# Hashtags Used:[]
# Tweet 12:
# Username:GennieRoo
# Description:🌼Daydream believer
# 🌼Here for whimsy
# Location:Somewhere In, TN
# Following Count:586
# Follower Count:140
# Total Tweets:2925
# Retweet Count:0
# Tweet Text:@KitThoughts_ @ericandre @JoeBiden guys don't want them going to jail anymore. What about the people they hurt? How do you want the court system to treat them? How do you want the court system to differentiate between the addict refusing treatment, stealing, etc.?
# Hashtags Used:[]
# Tweet 13:
# Username:fancyeagledance
# Description:If only there were free and fair elections in the US.  Term limits now.
# Location:
# Following Count:2915
# Follower Count:829
# Total Tweets:63230
# Retweet Count:570
# Tweet Text:Why are reporters not covering the fact that @JoeBiden, @jakejsullivan, etc. are clearing out career public servants on the National Security Council, in the IC, etc.? We were told before that these people serve presidents of both parties &amp; replacing them would hurt NatSec. 🤔
# Hashtags Used:[]
# Tweet 14:
# Username:Native615
# Description:I believe in science, facts, climate change, and true compassion for others. while we don't all have to agree, we can be civil.
# Location:
# Following Count:786
# Follower Count:252
# Total Tweets:24966
# Retweet Count:1667
# Tweet Text:This is very good news. @JoeBiden is moving quickly to address the climate crisis. Now Congress needs to aggressively act to transition our energy system away from fossil fuels. https://t.co/IGW1JG9C4x
# Hashtags Used:[]
# Tweet 15:
# Username:sammytancl
# Description:True Egalitarian. Expose bad lope-sided ideas disguised as good. Spread attention to discussions that effect us daily. Make positive changes, a tweet at a time.
# Location:Singapore
# Following Count:120
# Follower Count:76
# Total Tweets:19766
# Retweet Count:0
# Tweet Text:Jacobin's Obvious Satire Flies Right Over Tim Pool’s Beanie https://t.co/NWKuFBTX4l @thehill @Google @TYT @AngryJoeShow @CNN @MSNBC @nytimes @time @foxandfriends @joerogan @facebook @JoeBiden @ANTHONYBLOGAN @TIME @Timcast @RubinReport @MTV @TheDemocrats @AOC @SpeakerPelosi
# Hashtags Used:[]
# Tweet 16:
# Username:winterschild11
# Description:Not much to say about myself, I love photography, writing, animals, and old movies
# Location:
# Following Count:883
# Follower Count:1008
# Total Tweets:224966
# Retweet Count:0
# Tweet Text:@mtgreenee @realDonaldTrump @JoeBiden @SebGorka Don’t you have some teenagers to stalk and harass?
# Hashtags Used:[]
# Tweet 17:
# Username:MakwanaMunnaBh2
# Description:munna bhai
# Location:
# Following Count:11
# Follower Count:8
# Total Tweets:544
# Retweet Count:57
# Tweet Text:#LRD_MALE_CENTRAL_JAIL
#
# Republic Day is of no importance to me, my brothers seeking justice are also in #LRD_MALE Sabarmati Jail(gujarat)
#
# We will celebrate our true Republic Day only when we get justice, otherwise all the days seem like black to us.
# @JoeBiden
# @CMOGuj
# Hashtags Used:['LRD_MALE_CENTRAL_JAIL', 'LRD_MALE']
# Tweet 18:
# Username:AmirAhm13232311
# Description:
# Location:
# Following Count:85
# Follower Count:20
# Total Tweets:54
# Retweet Count:266
# Tweet Text:It is imperative for Biden Administration to keep US FORCES in AFG to uphold U.S influence in the region by taking punitive actions against China &amp; ISI by refraining them to influence the peace process in AFG
#
# @ABlinken
# @JoeBiden
# @KamalaHarris
# @PMOIndia
# @ARS19622906
# @CIA
# Hashtags Used:[]
# Tweet 19:
# Username:iflakhan197
# Description:queen
# Location:
# Following Count:41
# Follower Count:123
# Total Tweets:162
# Retweet Count:266
# Tweet Text:It is imperative for Biden Administration to keep US FORCES in AFG to uphold U.S influence in the region by taking punitive actions against China &amp; ISI by refraining them to influence the peace process in AFG
#
# @ABlinken
# @JoeBiden
# @KamalaHarris
# @PMOIndia
# @ARS19622906
# @CIA
# Hashtags Used:[]
# Tweet 20:
# Username:Kaede_Doumyozi
# Description:
# Location:
# Following Count:931
# Follower Count:842
# Total Tweets:260135
# Retweet Count:36
# Tweet Text:I have just had a telephone conversation with President @JoeBiden, in which I congratulated him on his inauguration and discussed with him a range of substantive issues.
# Hashtags Used:[]
# Tweet 21:
# Username:Karabala19
# Description:
# Location:
# Following Count:3
# Follower Count:0
# Total Tweets:4
# Retweet Count:432
# Tweet Text:Dear @JoeBiden If we keep on this increase of minimum wage track, there will be a worldwide economic collapse. We need to balance the cost of living (housing, rent for living and small businesses, all insurance, food, etc). This is why #TheHumanityFoundation is so important!!😇⚖️ https://t.co/EtuowgWye4 https://t.co/RG2b7qJ5Ta
# Hashtags Used:[]
# Tweet 22:
# Username:Judicio88716056
# Description:
# Location:
# Following Count:63
# Follower Count:25
# Total Tweets:1070
# Retweet Count:1
# Tweet Text:@tigHagerey @Awet_GR @POTUS @VP @StateDept @TheEconomist @martinplaut Eritrean troops now staying in #Tigray in New uniforms IGNORING the US, EU  call for immediate withdrawal. #TigrayGenocide @statedeptspox @StateDRL @ABlinken @LindaT_G @wendyrsherman @JoeBiden @VP @WhiteHouse @YohannesAbraham @eu_eeas @GermanyDiplo @JosepBorrellF @HouseForeign
# Hashtags Used:['Tigray']
# Tweet 23:
# Username:Elshada37075062
# Description:
# Location:
# Following Count:79
# Follower Count:96
# Total Tweets:7551
# Retweet Count:151
# Tweet Text:#Eritrean soldiers working to cheat international community by wearing #Ethiopian military uniform.And also,no evidence was provided by the information minister of Eritrea to deny the #warcrimes their country has inflicted in #TigrayGenocide.    @JoeBiden  #BidenActNow
# Hashtags Used:['Eritrean', 'Ethiopian']
# Tweet 24:
# Username:Katefelix20
# Description:
# Location:w/ baby jimmy
# Following Count:519
# Follower Count:592
# Total Tweets:3488
# Retweet Count:0
# Tweet Text:@JoeBiden sucks as president he still hasn’t made @yncristinaa fall in love with me yet 🙄
# Hashtags Used:[]
# Tweet 25:
# Username:MSikimeti
# Description:
# Location:
# Following Count:1561
# Follower Count:594
# Total Tweets:51618
# Retweet Count:28
# Tweet Text:PS: (1) Can’t anyone else see that @JoeBiden was v. careful in what he said he’d do about climate, refugees &amp; so on before the election, but now AFTER the election he’s immediately doing heaps of amazing stuff?
#
# How on earth can ppl see that &amp; say Labor are hopeless?
# Hashtags Used:[]
# Tweet 26:
# Username:nycyanggang
# Description:Organizing account for the NY Humanity First Movement. Across NY-NJ Area as well as NY state. Not officially endorsed or sponsored by Andrew Yang.
# Location:New York, NY
# Following Count:1519
# Follower Count:3891
# Total Tweets:6803
# Retweet Count:12100
# Tweet Text:Dear @JoeBiden Now that you're the prez could u do a me a quick favor and undo your old crime bill, decriminalize all drugs, ban fracking, reunite immigrant families, eliminate the electoral college, cancel student loan debt, and say yes to universal health care? Thanks bud! 🇺🇸
# Hashtags Used:[]
# Tweet 27:
# Username:MariannaFortune
# Description:I am woman, hear me roar
# Location:
# Following Count:500
# Follower Count:105
# Total Tweets:19371
# Retweet Count:0
# Tweet Text:She was awesome. It was better w @chrislhayes being her homeboy. She did equally well w @SHODesusAndMero a regular human being who is plain spoken.should do well w @JoeBiden .@POTUS should talk to @RepAOC &amp; #TheSquad| @SpeakerPelosi @VP @RepRashida @RepPressley @Ilhan @FLOTUS https://t.co/K6eQpNnCDn
# Hashtags Used:['TheSquad']
# Tweet 28:
# Username:DavidStrayer10
# Description:Retired-Rewired hobby Political analyst/forecasters.😃 🌊
# Location:
# Following Count:534
# Follower Count:134
# Total Tweets:3257
# Retweet Count:380
# Tweet Text:.@JoeBiden became President of the United States today. Period. 😉
# Hashtags Used:[]
# Tweet 29:
# Username:AgainBraine
# Description:Londoner, patriot
# Location:
# Following Count:277
# Follower Count:1007
# Total Tweets:27679
# Retweet Count:11
# Tweet Text:@BorisJohnson @JoeBiden Isn't it an amazing coincidence that all of these policies just happen to be UN ones. Vote Tory, get the UN.
# Hashtags Used:[]
# Tweet 30:
# Username:ShainaIsaacs
# Description:Mother of 5, 1 child with the angels 👼 Rest easy Adamke my kleine boobalei, photo taken in Tel Aviv, Israel. His twin sister by his side
# Location:Melbourne
# Following Count:448
# Follower Count:73
# Total Tweets:2069
# Retweet Count:0
# Tweet Text:@LindseyGrahamSC must have been given a reality check by @JoeBiden He’s back on #FOX w deluded malice &amp; sucking up #TrumpTreason w @seanhannity #GOPSeditiousTraitors #ImpeachAndConvict #EnoughIsEnough
# Hashtags Used:['FOX', 'TrumpTreason', 'GOPSeditiousTraitors', 'ImpeachAndConvict', 'EnoughIsEnough']
# Tweet 31:
# Username:XOTankieTingz
# Description:☭ because the Bible told me so✝️🧘🏾‍♀️-loving, 🎾-playing, Roller Bae 🎱💋La Belle Dame Sans Merci🥀Scribe✍🏾زهرة القاتلة🥴#alwayshighonhere🍃🌬
# Location:Salish Land 🇻🇪🇵🇸🇨🇺🇰🇵
# Following Count:1556
# Follower Count:2199
# Total Tweets:100477
# Retweet Count:12100
# Tweet Text:Dear @JoeBiden Now that you're the prez could u do a me a quick favor and undo your old crime bill, decriminalize all drugs, ban fracking, reunite immigrant families, eliminate the electoral college, cancel student loan debt, and say yes to universal health care? Thanks bud! 🇺🇸
# Hashtags Used:[]
# Tweet 32:
# Username:RedfireBlueice
# Description:🐱mom,animal & nature ❤️👩‍🎨📷 anime,music,movie,history & space enthusiast.🇵🇱 🇭🇳#Independent #TheResistance #TrumpImpeachedForever #RIPGOP I block Aholes
# Location:
# Following Count:2675
# Follower Count:1999
# Total Tweets:76734
# Retweet Count:32
# Tweet Text:@JoeBiden Trump lied. There's no stockpile. He gave it his friends and family.
# Hashtags Used:[]
# Tweet 33:
# Username:Sergiy1975Zorro
# Description:engineer, manager and just a happy father and husband from Ukraine
# Location:
# Following Count:145
# Follower Count:29
# Total Tweets:1580
# Retweet Count:0
# Tweet Text:@VP #DV2020 need your help!!We are DIVERSITY VISA holders, We’ve been waiting for almost 2 years, our visas will expire in early March, please help us to remove Trumps proclamation PP10014 and related! We’re running out of time #dv2020 #immigrants #noban @JoeBiden @WhiteHouse @POTUS
# Hashtags Used:['DV2020', 'dv2020', 'immigrants', 'noban']
# Tweet 34:
# Username:vaneroor
# Description:Wedding & Event Planner
# Location:Boca del Río, Veracruz de Ignacio de la Llave
# Following Count:136
# Follower Count:41
# Total Tweets:284
# Retweet Count:4754
# Tweet Text:To Pilar, and the countless other small business owners across the country, know that help is on the way. https://t.co/4mKPjN6rgx
# Hashtags Used:[]
# Tweet 35:
# Username:petercwillis
# Description:
# Location:Atlanta, Georgia
# Following Count:490
# Follower Count:34
# Total Tweets:290
# Retweet Count:0
# Tweet Text:@alexwalton71 @POTUS @realDonaldTrump @JoeBiden They can tell it’s you being silly.
# Hashtags Used:[]
# Tweet 36:
# Username:BrandonPlanY
# Description:@FullSail University Graduate MCCert Certificate Program Blognews2099by@gmail.com BrandonComedicSoup @SEGA @Surfer @HIDEO_KOJIMA_EN @usairforce @wsl
# Location:USA
# Following Count:361
# Follower Count:27
# Total Tweets:576
# Retweet Count:1
# Tweet Text:Countries impose travel bans to isolate Britain's mutated coronavirus st... https://t.co/wB5jc3uvVM via @YouTube @JoeBiden @WhiteHouse @COVID19Tracking @COVIDNewsByMIB @WHCOVIDResponse @LDN_gov @MayorofLondon Mutation is more contagious and dangerous than Coronavirus level (1)
# Hashtags Used:[]
# Tweet 37:
# Username:VallecilloMary
# Description:🇭🇳🇺🇸, Mother, Wife, & Biochemist Scientist. Passionate Muscle Diseases Researcher @ Brigham Young University #BYU. Family, Photography, Jazz & Bossa-nova
# Location:Orem, Utah
# Following Count:857
# Follower Count:2167
# Total Tweets:5261
# Retweet Count:11
# Tweet Text:Science is back!!!! Fantastic #WhiteHousePressBriefing with @CDCDirector and @NIH . Thank you, @JoeBiden and @KamalaHarris for working toward a true national response. #StrongerTogether https://t.co/usasPETuAF
# Hashtags Used:['WhiteHousePressBriefing']
# Tweet 38:
# Username:deb_schillinger
# Description:Wife to 1, Mom to 3, Grandma to 9, Liberal hippie, classic rock, Christian, animal & nature lover, #BLM, #bekind, have been known to cuss a little.
# Location:Montana, USA
# Following Count:413
# Follower Count:101
# Total Tweets:572
# Retweet Count:2
# Tweet Text:@SteveDaines @JoeBiden There are way more jobs in renewables. The fossil fuel industry is on the way out. Daines needs to stop lying and pandering to these people and get to work smoothing out the transition that is underway. No different than when railroads replaced riverboats.
# Hashtags Used:[]
# Tweet 39:
# Username:BayView72901143
# Description:The human condition
# Location:The only earth
# Following Count:912
# Follower Count:140
# Total Tweets:6252
# Retweet Count:52
# Tweet Text:Anybody who had anything to do with child separation should be fired immediately. @JoeBiden
# Hashtags Used:[]
# Tweet 40:
# Username:Arcarsenal09
# Description:No one sleeps when there's a snake on the roof. That snake right now is racism. #Wearamask
# Location:United States
# Following Count:953
# Follower Count:352
# Total Tweets:102904
# Retweet Count:12100
# Tweet Text:Dear @JoeBiden Now that you're the prez could u do a me a quick favor and undo your old crime bill, decriminalize all drugs, ban fracking, reunite immigrant families, eliminate the electoral college, cancel student loan debt, and say yes to universal health care? Thanks bud! 🇺🇸
# Hashtags Used:[]
# Tweet 41:
# Username:JasiyaKarim
# Description:traveller
# Location:
# Following Count:32
# Follower Count:93
# Total Tweets:155
# Retweet Count:269
# Tweet Text:It is imperative for Biden Administration to keep US FORCES in AFG to uphold U.S influence in the region by taking punitive actions against China &amp; ISI by refraining them to influence the peace process in AFG
#
# @ABlinken
# @JoeBiden
# @KamalaHarris
# @PMOIndia
# @ARS19622906
# @CIA
# Hashtags Used:[]
# Tweet 42:
# Username:LalasabNadaf16
# Description:Bsc(Hons) Agriculture,College of agriculture Raichur, Karnataka.
# Have faith in democracy
# Location:Karnataka, India
# Following Count:238
# Follower Count:121
# Total Tweets:5848
# Retweet Count:1171
# Tweet Text:US President @JoeBiden excludes Democrats with RSS-BJP links. Well Done. #BoycottBJP
# https://t.co/quV4snAR0o
# Hashtags Used:['BoycottBJP']
# Tweet 43:
# Username:Austinboiiii1
# Description:~Artist~
# Location:
# Following Count:43
# Follower Count:232
# Total Tweets:4152
# Retweet Count:12100
# Tweet Text:Dear @JoeBiden Now that you're the prez could u do a me a quick favor and undo your old crime bill, decriminalize all drugs, ban fracking, reunite immigrant families, eliminate the electoral college, cancel student loan debt, and say yes to universal health care? Thanks bud! 🇺🇸
# Hashtags Used:[]
# Tweet 44:
# Username:Shasta_Otter
# Description:queer polyamorous furry boy. 29. cis. he/him. SJW. Loves @osakacat. Christian. Seahawks fan. icon by @slimgiltsoul. #blacklivesmatter
# Location:Philadelphia, PA
# Following Count:2951
# Follower Count:1419
# Total Tweets:471514
# Retweet Count:1633
# Tweet Text:One more day to not be disgusting liars @ossoff @JoeBiden!  https://t.co/JLUIspM8ic
# Hashtags Used:[]
# Tweet 45:
# Username:Harperblammo
# Description:That was a glorious clusterfuck.
# Location:
# Following Count:679
# Follower Count:985
# Total Tweets:80221
# Retweet Count:0
# Tweet Text:@ANCALERTS FYI:
# It is not true that Pres.
# @JoeBiden's Rolex was his late son's watch.
# A White House official has confirmed to Mediaite that the timepiece worn at the president's swearing-in was actually a Christmas gift from the first lady, Dr. Jill Biden.
# https://t.co/F31hNiZCqd
# Hashtags Used:[]
# Tweet 46:
# Username:Isidro__Lopez
# Description:"Live Fast pet dogs"
#
# Subway™
# Location:South Oroville, CA
# Following Count:322
# Follower Count:23
# Total Tweets:1188
# Retweet Count:110
# Tweet Text:if you say so 😈 https://t.co/TNZuphBfAj
# Hashtags Used:[]
# Tweet 47:
# Username:RealityFreind
# Description:HUMAN
# Location:
# Following Count:60
# Follower Count:3
# Total Tweets:783
# Retweet Count:136
# Tweet Text:“Eritrean soldiers went house-to-house seeking out and killing Tigrayan men and boys, some as young as 7, they would kill you for trying, or even crying” @priyankachopra @POTUS @JoeBiden @VP @ABlinken #TigrayGenocide #BidenActNow
# https://t.co/cH9o18DAYf
# Hashtags Used:[]
# Tweet 48:
# Username:paulchibuezeonu
# Description:Britain backs killin in Islamic stat of Nigeria free Biafra & light will come 2 Africa & illegal migrant 2 Europe reduce by 40%
# Biafra means come & join(asylum)
# Location:biafra
# Following Count:4919
# Follower Count:2650
# Total Tweets:117413
# Retweet Count:9
# Tweet Text:Pulled out from their house and killed in Bambui my the military of Paul biya. The world is wicket. If this is not genocide what do we call it? @antonioguterres @VP @Michel61B @JoeBiden https://t.co/Q1xWoAZdso
# Hashtags Used:[]
# Tweet 49:
# Username:davidloddls23
# Description:Good Day  Everyone 💙💙💙
# Location:San Francisco, CA
# Following Count:2780
# Follower Count:56
# Total Tweets:596
# Retweet Count:14
# Tweet Text:.@WadeCrowfoot, @calnatresources Sec, says @JoeBiden will better fund CA's federal land management.
#
# Last year, 5 out of the 6 largest fires in CA history were burning AT THE SAME TIME.
#
# He says @CAgovernor @GavinNewsom recently committed $1 billion for wildfire prevention. https://t.co/ERBhJf3tut
# Hashtags Used:[]
# Tweet 50:
# Username:Nitro_Savage92
# Description:I am going to be hated anyways. That's life, you can't satisfy the world.
#
# The world is filled with Make-believe.
#
# It's facts not Fiction.
# Location:Facts, VA Wastelands
# Following Count:5002
# Follower Count:276
# Total Tweets:20129
# Retweet Count:420
# Tweet Text:Nothing to see here, just Black Lives Mattering.
#
# @JoeBiden if I didn’t think you were too senile to read, I’d tell you what I really think of you. https://t.co/tjOPiiGMN9
# Hashtags Used:[]
# Tweet 51:
# Username:PRANABRAHA5
# Description:
# Location:
# Following Count:26
# Follower Count:4
# Total Tweets:1914
# Retweet Count:15268
# Tweet Text:My warmest congratulations to @JoeBiden on his assumption of office as President of the United States of America. I look forward to working with him to strengthen India-US strategic partnership.
# Hashtags Used:[]
# Tweet 52:
# Username:Soleful151
# Description:🙏🏾
# Location:
# Following Count:244
# Follower Count:105
# Total Tweets:527
# Retweet Count:151
# Tweet Text:#Eritrean soldiers working to cheat international community by wearing #Ethiopian military uniform.And also,no evidence was provided by the information minister of Eritrea to deny the #warcrimes their country has inflicted in #TigrayGenocide.    @JoeBiden  #BidenActNow
# Hashtags Used:['Eritrean', 'Ethiopian']
# Tweet 53:
# Username:Infwhale
# Description:Amateur Sci-fi Author & Long time Digital Artist. UA Professional and avid VR Gamer.
# Location:Aveone
# Following Count:666
# Follower Count:390
# Total Tweets:34267
# Retweet Count:557
# Tweet Text:FIRST THINGS FIRST MR PRESIDENT @POTUS @JOEBIDEN
# PLEASE TAKE THE FIRST STEP
# TOWARD SAVING DEMOCRACY
# PARDON #JULIANASSANGE
# IF HE GOES WE ALL GO
# AND THEN WE CAN THROW AWAY OUR KEYS https://t.co/iN9pCBagme
# Hashtags Used:['JULIANASSANGE']
# Tweet 54:
# Username:RisGeb
# Description:friend
# Location:
# Following Count:70
# Follower Count:14
# Total Tweets:915
# Retweet Count:151
# Tweet Text:#Eritrean soldiers working to cheat international community by wearing #Ethiopian military uniform.And also,no evidence was provided by the information minister of Eritrea to deny the #warcrimes their country has inflicted in #TigrayGenocide.    @JoeBiden  #BidenActNow
# Hashtags Used:['Eritrean', 'Ethiopian']
# Tweet 55:
# Username:IqraMus82142091
# Description:love India
# Location:
# Following Count:32
# Follower Count:87
# Total Tweets:153
# Retweet Count:269
# Tweet Text:It is imperative for Biden Administration to keep US FORCES in AFG to uphold U.S influence in the region by taking punitive actions against China &amp; ISI by refraining them to influence the peace process in AFG
#
# @ABlinken
# @JoeBiden
# @KamalaHarris
# @PMOIndia
# @ARS19622906
# @CIA
# Hashtags Used:[]
# Tweet 56:
# Username:ph_estrada4167
# Description:Christian, conservative, Republican, in that order.
# Location:
# Following Count:94
# Follower Count:28
# Total Tweets:9195
# Retweet Count:192
# Tweet Text:Except the science of when a human life begins. Mr. President, you do not respect science and worse, you do not respect the most basic of human rights for our most vulnerable. @JoeBiden https://t.co/a7BrJNl84I
# Hashtags Used:[]
# Tweet 57:
# Username:oluotawa66
# Description:
# Location:
# Following Count:468
# Follower Count:30
# Total Tweets:273
# Retweet Count:7958
# Tweet Text:Anyone who wants to get to @JoeBiden, will have to get past us first 💪⚡️👊😜
#
# We may not look intimidating, but remember, our Nana is @DrBiden... https://t.co/6R1zlpmy9p
# Hashtags Used:[]
# Tweet 58:
# Username:Mzeesha20369978
# Description:
# Location:
# Following Count:71
# Follower Count:10
# Total Tweets:57
# Retweet Count:269
# Tweet Text:It is imperative for Biden Administration to keep US FORCES in AFG to uphold U.S influence in the region by taking punitive actions against China &amp; ISI by refraining them to influence the peace process in AFG
#
# @ABlinken
# @JoeBiden
# @KamalaHarris
# @PMOIndia
# @ARS19622906
# @CIA
# Hashtags Used:[]
# Tweet 59:
# Username:DanielB98312554
# Description:blahblahblah that's  all I hear from the left, SHUT THE HE'LL UP ALREADY!!!
# Location:Pennsylvania, USA
# Following Count:173
# Follower Count:39
# Total Tweets:2808
# Retweet Count:420
# Tweet Text:Nothing to see here, just Black Lives Mattering.
#
# @JoeBiden if I didn’t think you were too senile to read, I’d tell you what I really think of you. https://t.co/tjOPiiGMN9
# Hashtags Used:[]
# Tweet 60:
# Username:Hereonly4ssr
# Description:Joined twitter only for SSR! “Following, links & Retweets ≠ endorsements”. “My religion is very simple. My religion is kindness.” ― His Holiness Dalai Lama XIV
# Location:USA
# Following Count:454
# Follower Count:319
# Total Tweets:8541
# Retweet Count:0
# Tweet Text:This is happening in New York of all places, tomorrow they might demand a Khalsitan in the US. Hope you are watching! God bless America!!!🇺🇸
# @WhiteHouse @POTUS @JoeBiden @CIA @FBI https://t.co/6qe3lsab4Q
# Hashtags Used:[]
# Tweet 61:
# Username:RayJoubert
# Description:
# Location:Switzerland
# Following Count:354
# Follower Count:115
# Total Tweets:7889
# Retweet Count:3
# Tweet Text:@ReesusP @jack Russian #Mole conning Americans. @JoeBiden @KamalaHarris @glennkirschner2 @MittRomney @ossoff @ReverendWarnock @maddow @AliVelshi @donlemon  @nytopinion @PostOpinions @voxdotcom @BuzzFeedNews @BarackObama @JohnBrennan  #Helsinki Private conversation #Collusion @GOPLeader https://t.co/TulCc96nxi https://t.co/bxWNxUE36M
# Hashtags Used:['Mole']
# Tweet 62:
# Username:klaretsky
# Description:PATRIOT
# Location:
# Following Count:52
# Follower Count:4
# Total Tweets:158
# Retweet Count:1768
# Tweet Text:I see @JoeBiden as a TRAITOR to America!
#
# Do you?
# Hashtags Used:[]
# Tweet 63:
# Username:Bossgto65
# Description:Just a regular Joe bag of donuts guy!
# Location:N.E Ohio
# Following Count:26
# Follower Count:234
# Total Tweets:16692
# Retweet Count:3477
# Tweet Text:Did @joebiden forget about this? https://t.co/LF7rvk9kUx
# Hashtags Used:[]
# Tweet 64:
# Username:MWoldegerima
# Description:ትግራወይቲ❤️💛 | Nutrition | ✝️ |
# Never give up on what you believe, and never give up until it's achieved.
# Location:South Australia
# Following Count:56
# Follower Count:43
# Total Tweets:335
# Retweet Count:0
# Tweet Text:Reports of #Eritrea|an troops staying in #Tigray with Ethiopian Army uniforms to block humanitarian corridor. @JoeBiden @POTUS @VP @SecBlinken
# @jakejsullivan
# #EritreaOutOfTigray #TigrayGenocide #TigrayCantWait
# Hashtags Used:['Eritrea', 'Tigray', 'EritreaOutOfTigray', 'TigrayGenocide', 'TigrayCantWait']
# Tweet 65:
# Username:DjC_777
# Description:
# Location:
# Following Count:151
# Follower Count:29
# Total Tweets:1070
# Retweet Count:0
# Tweet Text:@tomselliott @JoeBiden This didn't age well.
# Hashtags Used:[]
# Tweet 66:
# Username:unseen_devil
# Description:Indian
# Location:India
# Following Count:475
# Follower Count:482
# Total Tweets:14108
# Retweet Count:1171
# Tweet Text:US President @JoeBiden excludes Democrats with RSS-BJP links. Well Done. #BoycottBJP
# https://t.co/quV4snAR0o
# Hashtags Used:['BoycottBJP']
# Tweet 67:
# Username:nancy_digi
# Description:
# Location:
# Following Count:291
# Follower Count:17
# Total Tweets:1096
# Retweet Count:420
# Tweet Text:Nothing to see here, just Black Lives Mattering.
#
# @JoeBiden if I didn’t think you were too senile to read, I’d tell you what I really think of you. https://t.co/tjOPiiGMN9
# Hashtags Used:[]
# Tweet 68:
# Username:lil_uzi_maki
# Description:im barely payin attention babbyyyyyy i need substance //// all my sports teams are mids
# Location:Saginaw, MI
# Following Count:499
# Follower Count:358
# Total Tweets:50500
# Retweet Count:152
# Tweet Text:niggas owe you money then stop tweeting for a week 🤡 https://t.co/8lTMehBZz6
# Hashtags Used:[]
# Tweet 69:
# Username:WatchYouDie1981
# Description:Leftist. Satanist. BLM. M4A. Green New Deal. Abolish the police.
# Location:Idaho, USA
# Following Count:1945
# Follower Count:1189
# Total Tweets:588
# Retweet Count:12100
# Tweet Text:Dear @JoeBiden Now that you're the prez could u do a me a quick favor and undo your old crime bill, decriminalize all drugs, ban fracking, reunite immigrant families, eliminate the electoral college, cancel student loan debt, and say yes to universal health care? Thanks bud! 🇺🇸
# Hashtags Used:[]
# Tweet 70:
# Username:SidratMuntaha7
# Description:
# Location:
# Following Count:32
# Follower Count:39
# Total Tweets:148
# Retweet Count:269
# Tweet Text:It is imperative for Biden Administration to keep US FORCES in AFG to uphold U.S influence in the region by taking punitive actions against China &amp; ISI by refraining them to influence the peace process in AFG
#
# @ABlinken
# @JoeBiden
# @KamalaHarris
# @PMOIndia
# @ARS19622906
# @CIA
# Hashtags Used:[]
# Tweet 71:
# Username:AsifMuj07901815
# Description:
# Location:
# Following Count:193
# Follower Count:35
# Total Tweets:57
# Retweet Count:269
# Tweet Text:It is imperative for Biden Administration to keep US FORCES in AFG to uphold U.S influence in the region by taking punitive actions against China &amp; ISI by refraining them to influence the peace process in AFG
#
# @ABlinken
# @JoeBiden
# @KamalaHarris
# @PMOIndia
# @ARS19622906
# @CIA
# Hashtags Used:[]
# Tweet 72:
# Username:al3xtec
# Description:I wasn't born with enough middle fingers!
# 凸ಠ益ಠ)凸
# He/Him/His (Bi)🏳️‍🌈
# Black Lives Matter!
# #AlwaysAntiFascist #DSA #Med4All #PDX
# Location:Portland, OR
# Following Count:632
# Follower Count:107
# Total Tweets:7800
# Retweet Count:0
# Tweet Text:#Portland #Holocaust remembrance day vigil about to be gassed by @ICEgov.
# @JoeBiden @HolocaustMuseum
# @VP
#
# https://t.co/U5PfpX67bP
# Hashtags Used:['Portland', 'Holocaust']
# Tweet 73:
# Username:metal_foxx
# Description:I love playing fighting games like
# Skullgirls, Street fighter and PowerRangersBFTG
# He/Him. Age 19. play #BattleForTheGrid
# #PlaySkullgirls
# #PlayPokken
# Location:Texas, USA
# Following Count:395
# Follower Count:65
# Total Tweets:18383
# Retweet Count:420
# Tweet Text:Nothing to see here, just Black Lives Mattering.
#
# @JoeBiden if I didn’t think you were too senile to read, I’d tell you what I really think of you. https://t.co/tjOPiiGMN9
# Hashtags Used:[]
# Tweet 74:
# Username:mattjjduhamel
# Description:
# Location:Rocky Mountain House, Alberta
# Following Count:22
# Follower Count:2
# Total Tweets:6
# Retweet Count:0
# Tweet Text:Damn they really haven't patched the infinite money glitch yet eh? #joebiden #AMC #reddit #gamestonk #GMEtothemoon
# #wallstreetbets https://t.co/jORfnxoyGe
# Hashtags Used:['joebiden', 'AMC', 'reddit', 'gamestonk', 'GMEtothemoon', 'wallstreetbets']
# Tweet 75:
# Username:msghfbdhgg
# Description:
# Location:
# Following Count:1
# Follower Count:0
# Total Tweets:15
# Retweet Count:1172
# Tweet Text:US President @JoeBiden excludes Democrats with RSS-BJP links. Well Done. #BoycottBJP
# https://t.co/quV4snAR0o
# Hashtags Used:['BoycottBJP']
# Tweet 76:
# Username:ZanduOm
# Description:
# Location:Ambala, India
# Following Count:8
# Follower Count:1
# Total Tweets:761
# Retweet Count:309
# Tweet Text:First official public contact between PM @narendramodi and US President @JoeBiden governments; find out what they spoke about.
#
# #LalQuilaHamaraHai
#
# https://t.co/2qzlAymgwG
# Hashtags Used:[]
# Tweet 77:
# Username:roxbri57
# Description:
# Location:Clifton, CO
# Following Count:223
# Follower Count:55
# Total Tweets:1476
# Retweet Count:0
# Tweet Text:@stinchfield1776 @JoeBiden Praying for our oilfield workers
# Hashtags Used:[]
# Tweet 78:
# Username:staytravelin
# Description:Elections have consequences. Black lives matter, period. Drawn to doomed TV shows. Pineapple on pizza lover. $staytravelin
# Location:
# Following Count:964
# Follower Count:796
# Total Tweets:63577
# Retweet Count:733
# Tweet Text:So when it happens don’t blame @JoeBiden and the @TheDemocrats.  This was him protecting the wealthy and using his “base” to get it done. https://t.co/JXXJjl8od0
# Hashtags Used:[]
# Tweet 79:
# Username:meron28082125
# Description:
# Location:
# Following Count:75
# Follower Count:24
# Total Tweets:1204
# Retweet Count:0
# Tweet Text:@Brian_Higgz @UNHumanRights @UN smart!!! yes u do know him this evil butcher and the main Actor Esyas Afowerki GOD will show us there end as they lie to the world what would be there answer when @JoeBiden ordered investigators  enter to Tigray what is gonna there answer? i cant wait Tigray is not one room
# Hashtags Used:[]
# Tweet 80:
# Username:sgmapt
# Description:COME HELL OR HIGH WATER:
# Goodbye GOP! Goodbye T***p!  Goodbye white supremacists and other deplorable scum. Goodbye and Good Riddance! #BLM #diversity #empathy
# Location:
# Following Count:2579
# Follower Count:2072
# Total Tweets:73995
# Retweet Count:733
# Tweet Text:So when it happens don’t blame @JoeBiden and the @TheDemocrats.  This was him protecting the wealthy and using his “base” to get it done. https://t.co/JXXJjl8od0
# Hashtags Used:[]
# Tweet 81:
# Username:TigraiAdey
# Description:#Tigrai Tweets
# Location:ትግራይ
# Following Count:149
# Follower Count:971
# Total Tweets:4607
# Retweet Count:0
# Tweet Text:"A medical worker in Adigrat said he treated six women who had been raped by a group of soldiers &amp; told not to seek help afterwards." The int'l community has the #R2P civilians from rape and war crimes. #Tigray @DominicRaab @JoeBiden @UN #TigrayGenocide
# https://t.co/WnI8CTpLX3
# Hashtags Used:['R2P', 'Tigray', 'TigrayGenocide']
# Tweet 82:
# Username:yamaralige
# Description:
# Location:
# Following Count:36
# Follower Count:1
# Total Tweets:135
# Retweet Count:151
# Tweet Text:#Eritrean soldiers working to cheat international community by wearing #Ethiopian military uniform.And also,no evidence was provided by the information minister of Eritrea to deny the #warcrimes their country has inflicted in #TigrayGenocide.    @JoeBiden  #BidenActNow
# Hashtags Used:['Eritrean', 'Ethiopian']
# Tweet 83:
# Username:daveyruss
# Description:Proud to be English & a true Cockney. On Parler @CockneyDave
#
# Pro Brexit, pro Trump. Anti far left fascists.
#
# Brexit voter along with 17,410,741 other patriots
# Location:Wiltshire
# Following Count:2106
# Follower Count:2049
# Total Tweets:36115
# Retweet Count:0
# Tweet Text:@BorisJohnson @JoeBiden There is a reason the green party has only EVER had 1 MP, green agenda has failed over and over, costs us billions, makes the poor poorer. Your party best speaks up to stop this BS we did not vote for, or the Tories will be finished just like labour
# Hashtags Used:[]
# Tweet 84:
# Username:NawreenF
# Description:
# Location:
# Following Count:44
# Follower Count:43
# Total Tweets:148
# Retweet Count:269
# Tweet Text:It is imperative for Biden Administration to keep US FORCES in AFG to uphold U.S influence in the region by taking punitive actions against China &amp; ISI by refraining them to influence the peace process in AFG
#
# @ABlinken
# @JoeBiden
# @KamalaHarris
# @PMOIndia
# @ARS19622906
# @CIA
# Hashtags Used:[]
# Tweet 85:
# Username:athomeinbklyn
# Description:Topics: Voting Elections Bread Bicycles Urbanism
# Location:Brooklyn, NY
# Following Count:4558
# Follower Count:626
# Total Tweets:6509
# Retweet Count:0
# Tweet Text:@JoeBiden @RonaldKlain @celinegounder @ZekeEmanuel @RWalensky @DrBiden
# Hi all!  Really hoping you guys invoke the DPA for N95’s (#DPA4N95 ) right off the bat.
#
# This would be a huge "we hear you" acknowledgement.
#
# Thank you very much for your time!
#
# Pulling for you! https://t.co/XDLmqT9gBd
# Hashtags Used:[]
# Tweet 86:
# Username:asqual_berhe
# Description:
# Location:
# Following Count:84
# Follower Count:30
# Total Tweets:2413
# Retweet Count:151
# Tweet Text:#Eritrean soldiers working to cheat international community by wearing #Ethiopian military uniform.And also,no evidence was provided by the information minister of Eritrea to deny the #warcrimes their country has inflicted in #TigrayGenocide.    @JoeBiden  #BidenActNow
# Hashtags Used:['Eritrean', 'Ethiopian']
# Tweet 87:
# Username:stray_talk
# Description:Proud mum of one cat.
# Style, control, damage and aggression.
# She / ya gal
# Location:Glasgow 🏴󠁧󠁢󠁳󠁣󠁴󠁿 🇪🇺
# Following Count:180
# Follower Count:106
# Total Tweets:5676
# Retweet Count:30
# Tweet Text:Really hoping @JoeBiden’s legacy is the President who finally fixed the briefing room kerning. https://t.co/SZnJ064GEA
# Hashtags Used:[]
# Tweet 88:
# Username:TigraiAdey
# Description:#Tigrai Tweets
# Location:ትግራይ
# Following Count:149
# Follower Count:971
# Total Tweets:4607
# Retweet Count:0
# Tweet Text:Accounts of rape and sexual violence in the ongoing #WarOnTigray are not only "disturbing," but frequent.  #BidenActNow to protect #Tigray|ans in #Ethiopia from becoming victims of more sex crimes. @DominicRaab @JoeBiden @UN #TigrayGenocide
# https://t.co/X9tRTidClc
# Hashtags Used:['WarOnTigray', 'BidenActNow', 'Tigray', 'Ethiopia', 'TigrayGenocide']
# Tweet 89:
# Username:ts_melay
# Description:Global Citizen
# Location:United States
# Following Count:128
# Follower Count:28
# Total Tweets:2096
# Retweet Count:151
# Tweet Text:#Eritrean soldiers working to cheat international community by wearing #Ethiopian military uniform.And also,no evidence was provided by the information minister of Eritrea to deny the #warcrimes their country has inflicted in #TigrayGenocide.    @JoeBiden  #BidenActNow
# Hashtags Used:['Eritrean', 'Ethiopian']
# Tweet 90:
# Username:MumtazLone6
# Description:
# Location:
# Following Count:97
# Follower Count:31
# Total Tweets:63
# Retweet Count:269
# Tweet Text:It is imperative for Biden Administration to keep US FORCES in AFG to uphold U.S influence in the region by taking punitive actions against China &amp; ISI by refraining them to influence the peace process in AFG
#
# @ABlinken
# @JoeBiden
# @KamalaHarris
# @PMOIndia
# @ARS19622906
# @CIA
# Hashtags Used:[]
# Tweet 91:
# Username:IndigenousArtst
# Description:
# Location:
# Following Count:28
# Follower Count:5
# Total Tweets:39
# Retweet Count:0
# Tweet Text:@POTUS @JoeBiden Well I'm certainly glad to see you got rid of that tRumper sign language interpreter! Someone there REALLY needs to get with the program on screening people!
#
# https://t.co/ucU6Suj3nF
# Hashtags Used:[]
# Tweet 92:
# Username:LaurenR86716420
# Description:Are we there yet?
# Location:Long Beach, CA
# Following Count:790
# Follower Count:69
# Total Tweets:2877
# Retweet Count:1
# Tweet Text:@TWEETIE814 @HoneyLight @harrisonjaime @Mrs_Dawn_Aquino @JoeBiden @TheDemocrats We all been asking that question in South Carolina because the white folks didn’t want Graham to win! Every where you went they were reminding the black folks to vote and telling us they were going to vote Democrat this time!
# Hashtags Used:[]
# Tweet 93:
# Username:OhFaro
# Description:Democrat. 3rd generation Californian - My grandparents worked the fields of OC in the 1930s. #BidenHarris2020 ❌NO DMs❌
# Location:#CA45
# Following Count:2336
# Follower Count:1576
# Total Tweets:89765
# Retweet Count:733
# Tweet Text:So when it happens don’t blame @JoeBiden and the @TheDemocrats.  This was him protecting the wealthy and using his “base” to get it done. https://t.co/JXXJjl8od0
# Hashtags Used:[]
# Tweet 94:
# Username:Dickofish
# Description:The main difference between Rats and People - Rats learn from Experience. This ain’t no party, this ain’t no disco
# Location:London, England
# Following Count:204
# Follower Count:27
# Total Tweets:1749
# Retweet Count:44
# Tweet Text:Heed my warnings @joebiden and @KamalaHarris. Read The Parasitic Mind to educate yourselves about these abhorrent notions. You will destroy our meritocratic ethos.  This is not progressive. It is antithetical to human nature. Humans are not social ants.
# Hashtags Used:[]
# Tweet 95:
# Username:1nterl0per
# Description:hi black lives still matter
# Location:he/they
# Following Count:478
# Follower Count:81
# Total Tweets:9054
# Retweet Count:12100
# Tweet Text:Dear @JoeBiden Now that you're the prez could u do a me a quick favor and undo your old crime bill, decriminalize all drugs, ban fracking, reunite immigrant families, eliminate the electoral college, cancel student loan debt, and say yes to universal health care? Thanks bud! 🇺🇸
# Hashtags Used:[]
# Tweet 96:
# Username:jennywackett
# Description:Funny mummy. Editor and writer. And, according to Piers Morgan, #ARabidFeminist
# Location:Somewhere
# Following Count:4682
# Follower Count:1866
# Total Tweets:67773
# Retweet Count:1
# Tweet Text:@BorisJohnson @JoeBiden Hi folks
#
# Boris Johnson here
#
# 100000 lives lost to Covid so I put on my sad face. That did the trick  👇
#
# Today I am making a completely unnecessary trip to Scotland
#
# Talk about that not the loss of life
#
# Catch you every time don’t I ? 😉
#
# #r4today #BBCBreakfast https://t.co/q9KFGaoeAW
# Hashtags Used:[]
# Tweet 97:
# Username:LaurenR86716420
# Description:Are we there yet?
# Location:Long Beach, CA
# Following Count:790
# Follower Count:69
# Total Tweets:2877
# Retweet Count:1
# Tweet Text:@HoneyLight @harrisonjaime @Mrs_Dawn_Aquino @JoeBiden @TheDemocrats I have been asking that same question!
# Hashtags Used:[]
# Tweet 98:
# Username:Barbara36687707
# Description:
# Location:
# Following Count:124
# Follower Count:14
# Total Tweets:13694
# Retweet Count:27
# Tweet Text:There’s no excuse for not having replaced @USBPChief already. Don’t forget that he justified &amp; supported separating families, gassed women &amp; children in Mexico &amp; was a proud member of the racist, violent Facebook group “I’m 10-15.” @JoeBiden
# Hashtags Used:[]
# Tweet 99:
# Username:Frakis21
# Description:If you can Cata Pult, then you can Cata Log.
# Location:TBD
# Following Count:1859
# Follower Count:295
# Total Tweets:24522
# Retweet Count:0
# Tweet Text:@Greg98071572 @vtbirkenstock @JoeBiden Sure. Politics is like drugs. Keep crying. It'll just get funnier as time goes on and you are shown to be more and more wrong with each passing day.
# Hashtags Used:[]
# Tweet 100:
# Username:LaurenR86716420
# Description:Are we there yet?
# Location:Long Beach, CA
# Following Count:790
# Follower Count:69
# Total Tweets:2877
# Retweet Count:15
# Tweet Text:@HoneyLight @harrisonjaime @Mrs_Dawn_Aquino @JoeBiden @TheDemocrats I agree with you. Jaime and Amy McGrath should have won! @AmyMcGrathKY
# Hashtags Used:[]
# Scraping has completed!
